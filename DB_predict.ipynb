# %%
#Importamos la librerías y variables necesarias
import mysql.connector
import sqlite3
import pandas as pd
from flask import Flask, jsonify, request
import pickle
import os
#################################################################################
#################################################################################
"""Definimos las variables generales para atacar la base de datos"""
#Definimos un cursor con el que atacar a la DB
cnx = mysql.connector.connect(
    user="admin",
    password="admin123",
    host="test-db.cze2nnbbx5pc.eu-west-3.rds.amazonaws.com",
    database="prueba")
cursor = cnx.cursor()
#Definimos una función mediante la que ejecutar las querys devolviendo un dataframe
def make_query(code):
    cursor.execute(code)
    results = cursor.fetchall()
    cnx.commit()
    return(results)
#Definimos una función mediante la que ejecutar las querys devolviendo un dataframe
def make_query_dataframe(code):
    cursor.execute(code)
    results = cursor.fetchall()
    column_names = [desc[0] for desc in cursor.description]  # Obtener los nombres de las columnas
    df = pd.DataFrame(results, columns=column_names)  # Crear el DataFrame
    return df

# %%
make_query("""CREATE TABLE predictions (
    id_employee INT,
    months_left DECIMAL(8,2),
    PRIMARY KEY (id_employee))"""
)
# Out:
# []

# %%
import numpy as np

# %%
numeros_aleatorios_prueba=np.random.randint(1,36,3698)
numeros_aleatorios_prueba
# Out:
# array([9, 8, 5, ..., 6, 9, 5])

# %%
df=pd.DataFrame(numeros_aleatorios_prueba).rename(columns={0:"months_left"}).reset_index()
df
# Out:
#       index  months_left
# 0         0            9
# 1         1            8
# 2         2            5
# 3         3           17
# 4         4           33
# ...     ...          ...
# 3693   3693           24
# 3694   3694           23
# 3695   3695            6
# 3696   3696            9
# 3697   3697            5
#
# [3698 rows x 2 columns]

# %%
# Cargar los datos del CSV a la tabla
for row in df.itertuples(index=False):
    values = ', '.join("'" + str(value).replace("'", "''") + "'" for value in row)
    query = f"INSERT INTO predictions VALUES ({values})"
    cursor.execute(query)
    print(row)
# Confirmar los cambios en la base de datos
cnx.commit()
# Cerrar el cursor y la conexión
cursor.close()
cnx.close()
# Out:
# Pandas(index=0, months_left=9)
# Pandas(index=1, months_left=8)
# Pandas(index=2, months_left=5)
# Pandas(index=3, months_left=17)
# Pandas(index=4, months_left=33)
# Pandas(index=5, months_left=8)
# Pandas(index=6, months_left=30)
# Pandas(index=7, months_left=21)
# Pandas(index=8, months_left=22)
# Pandas(index=9, months_left=25)
# Pandas(index=10, months_left=21)
# Pandas(index=11, months_left=16)
# Pandas(index=12, months_left=27)
# Pandas(index=13, months_left=2)
# Pandas(index=14, months_left=1)
# Pandas(index=15, months_left=16)
# Pandas(index=16, months_left=31)
# Pandas(index=17, months_left=27)
# Pandas(index=18, months_left=13)
# Pandas(index=19, months_left=28)
# Pandas(index=20, months_left=17)
# Pandas(index=21, months_left=30)
# Pandas(index=22, months_left=35)
# Pandas(index=23, months_left=2)
# Pandas(index=24, months_left=2)
# Pandas(index=25, months_left=33)
# Pandas(index=26, months_left=2)
# Pandas(index=27, months_left=35)
# Pandas(index=28, months_left=23)
# Pandas(index=29, months_left=7)
# Pandas(index=30, months_left=20)
# Pandas(index=31, months_left=21)
# Pandas(index=32, months_left=27)
# Pandas(index=33, months_left=22)
# Pandas(index=34, months_left=24)
# Pandas(index=35, months_left=17)
# Pandas(index=36, months_left=17)
# Pandas(index=37, months_left=26)
# Pandas(index=38, months_left=33)
# Pandas(index=39, months_left=21)
# Pandas(index=40, months_left=8)
# Pandas(index=41, months_left=15)
# Pandas(index=42, months_left=10)
# Pandas(index=43, months_left=5)
# Pandas(index=44, months_left=23)
# Pandas(index=45, months_left=2)
# Pandas(index=46, months_left=12)
# Pandas(index=47, months_left=20)
# Pandas(index=48, months_left=14)
# Pandas(index=49, months_left=10)
# Pandas(index=50, months_left=8)
# Pandas(index=51, months_left=16)
# Pandas(index=52, months_left=26)
# Pandas(index=53, months_left=21)
# Pandas(index=54, months_left=24)
# Pandas(index=55, months_left=24)
# Pandas(index=56, months_left=28)
# Pandas(index=57, months_left=2)
# Pandas(index=58, months_left=20)
# Pandas(index=59, months_left=24)
# Pandas(index=60, months_left=29)
# Pandas(index=61, months_left=30)
# Pandas(index=62, months_left=30)
# Pandas(index=63, months_left=34)
# Pandas(index=64, months_left=18)
# Pandas(index=65, months_left=9)
# Pandas(index=66, months_left=15)
# Pandas(index=67, months_left=7)
# Pandas(index=68, months_left=20)
# Pandas(index=69, months_left=16)
# Pandas(index=70, months_left=35)
# Pandas(index=71, months_left=31)
# Pandas(index=72, months_left=2)
# Pandas(index=73, months_left=2)
# Pandas(index=74, months_left=3)
# Pandas(index=75, months_left=22)
# Pandas(index=76, months_left=31)
# Pandas(index=77, months_left=15)
# Pandas(index=78, months_left=10)
# Pandas(index=79, months_left=35)
# Pandas(index=80, months_left=4)
# Pandas(index=81, months_left=16)
# Pandas(index=82, months_left=23)
# Pandas(index=83, months_left=5)
# Pandas(index=84, months_left=8)
# Pandas(index=85, months_left=18)
# Pandas(index=86, months_left=23)
# Pandas(index=87, months_left=1)
# Pandas(index=88, months_left=35)
# Pandas(index=89, months_left=34)
# Pandas(index=90, months_left=10)
# Pandas(index=91, months_left=28)
# Pandas(index=92, months_left=1)
# Pandas(index=93, months_left=17)
# Pandas(index=94, months_left=6)
# Pandas(index=95, months_left=31)
# Pandas(index=96, months_left=14)
# Pandas(index=97, months_left=22)
# Pandas(index=98, months_left=29)
# Pandas(index=99, months_left=7)
# Pandas(index=100, months_left=28)
# Pandas(index=101, months_left=8)
# Pandas(index=102, months_left=11)
# Pandas(index=103, months_left=21)
# Pandas(index=104, months_left=18)
# Pandas(index=105, months_left=8)
# Pandas(index=106, months_left=5)
# Pandas(index=107, months_left=2)
# Pandas(index=108, months_left=28)
# Pandas(index=109, months_left=19)
# Pandas(index=110, months_left=31)
# Pandas(index=111, months_left=35)
# Pandas(index=112, months_left=27)
# Pandas(index=113, months_left=21)
# Pandas(index=114, months_left=31)
# Pandas(index=115, months_left=17)
# Pandas(index=116, months_left=28)
# Pandas(index=117, months_left=19)
# Pandas(index=118, months_left=17)
# Pandas(index=119, months_left=17)
# Pandas(index=120, months_left=30)
# Pandas(index=121, months_left=2)
# Pandas(index=122, months_left=21)
# Pandas(index=123, months_left=28)
# Pandas(index=124, months_left=7)
# Pandas(index=125, months_left=13)
# Pandas(index=126, months_left=18)
# Pandas(index=127, months_left=11)
# Pandas(index=128, months_left=6)
# Pandas(index=129, months_left=2)
# Pandas(index=130, months_left=10)
# Pandas(index=131, months_left=18)
# Pandas(index=132, months_left=19)
# Pandas(index=133, months_left=31)
# Pandas(index=134, months_left=26)
# Pandas(index=135, months_left=30)
# Pandas(index=136, months_left=31)
# Pandas(index=137, months_left=18)
# Pandas(index=138, months_left=30)
# Pandas(index=139, months_left=25)
# Pandas(index=140, months_left=11)
# Pandas(index=141, months_left=23)
# Pandas(index=142, months_left=34)
# Pandas(index=143, months_left=15)
# Pandas(index=144, months_left=17)
# Pandas(index=145, months_left=2)
# Pandas(index=146, months_left=26)
# Pandas(index=147, months_left=26)
# Pandas(index=148, months_left=8)
# Pandas(index=149, months_left=9)
# Pandas(index=150, months_left=19)
# Pandas(index=151, months_left=11)
# Pandas(index=152, months_left=30)
# Pandas(index=153, months_left=23)
# Pandas(index=154, months_left=23)
# Pandas(index=155, months_left=13)
# Pandas(index=156, months_left=9)
# Pandas(index=157, months_left=12)
# Pandas(index=158, months_left=22)
# Pandas(index=159, months_left=31)
# Pandas(index=160, months_left=15)
# Pandas(index=161, months_left=23)
# Pandas(index=162, months_left=16)
# Pandas(index=163, months_left=22)
# Pandas(index=164, months_left=7)
# Pandas(index=165, months_left=4)
# Pandas(index=166, months_left=32)
# Pandas(index=167, months_left=7)
# Pandas(index=168, months_left=12)
# Pandas(index=169, months_left=4)
# Pandas(index=170, months_left=29)
# Pandas(index=171, months_left=27)
# Pandas(index=172, months_left=20)
# Pandas(index=173, months_left=8)
# Pandas(index=174, months_left=8)
# Pandas(index=175, months_left=28)
# Pandas(index=176, months_left=8)
# Pandas(index=177, months_left=30)
# Pandas(index=178, months_left=8)
# Pandas(index=179, months_left=9)
# Pandas(index=180, months_left=21)
# Pandas(index=181, months_left=15)
# Pandas(index=182, months_left=24)
# Pandas(index=183, months_left=13)
# Pandas(index=184, months_left=3)
# Pandas(index=185, months_left=29)
# Pandas(index=186, months_left=30)
# Pandas(index=187, months_left=25)
# Pandas(index=188, months_left=12)
# Pandas(index=189, months_left=20)
# Pandas(index=190, months_left=18)
# Pandas(index=191, months_left=25)
# Pandas(index=192, months_left=26)
# Pandas(index=193, months_left=5)
# Pandas(index=194, months_left=3)
# Pandas(index=195, months_left=21)
# Pandas(index=196, months_left=30)
# Pandas(index=197, months_left=14)
# Pandas(index=198, months_left=13)
# Pandas(index=199, months_left=34)
# Pandas(index=200, months_left=15)
# Pandas(index=201, months_left=20)
# Pandas(index=202, months_left=31)
# Pandas(index=203, months_left=3)
# Pandas(index=204, months_left=6)
# Pandas(index=205, months_left=25)
# Pandas(index=206, months_left=19)
# Pandas(index=207, months_left=34)
# Pandas(index=208, months_left=34)
# Pandas(index=209, months_left=23)
# Pandas(index=210, months_left=28)
# Pandas(index=211, months_left=35)
# Pandas(index=212, months_left=9)
# Pandas(index=213, months_left=12)
# Pandas(index=214, months_left=35)
# Pandas(index=215, months_left=17)
# Pandas(index=216, months_left=26)
# Pandas(index=217, months_left=35)
# Pandas(index=218, months_left=31)
# Pandas(index=219, months_left=33)
# Pandas(index=220, months_left=32)
# Pandas(index=221, months_left=12)
# Pandas(index=222, months_left=1)
# Pandas(index=223, months_left=19)
# Pandas(index=224, months_left=31)
# Pandas(index=225, months_left=7)
# Pandas(index=226, months_left=13)
# Pandas(index=227, months_left=9)
# Pandas(index=228, months_left=20)
# Pandas(index=229, months_left=17)
# Pandas(index=230, months_left=17)
# Pandas(index=231, months_left=35)
# Pandas(index=232, months_left=13)
# Pandas(index=233, months_left=31)
# Pandas(index=234, months_left=2)
# Pandas(index=235, months_left=31)
# Pandas(index=236, months_left=23)
# Pandas(index=237, months_left=32)
# Pandas(index=238, months_left=6)
# Pandas(index=239, months_left=17)
# Pandas(index=240, months_left=33)
# Pandas(index=241, months_left=24)
# Pandas(index=242, months_left=25)
# Pandas(index=243, months_left=22)
# Pandas(index=244, months_left=18)
# Pandas(index=245, months_left=23)
# Pandas(index=246, months_left=35)
# Pandas(index=247, months_left=23)
# Pandas(index=248, months_left=8)
# Pandas(index=249, months_left=22)
# Pandas(index=250, months_left=21)
# Pandas(index=251, months_left=9)
# Pandas(index=252, months_left=17)
# Pandas(index=253, months_left=18)
# Pandas(index=254, months_left=24)
# Pandas(index=255, months_left=35)
# Pandas(index=256, months_left=29)
# Pandas(index=257, months_left=7)
# Pandas(index=258, months_left=15)
# Pandas(index=259, months_left=5)
# Pandas(index=260, months_left=29)
# Pandas(index=261, months_left=12)
# Pandas(index=262, months_left=32)
# Pandas(index=263, months_left=15)
# Pandas(index=264, months_left=30)
# Pandas(index=265, months_left=32)
# Pandas(index=266, months_left=21)
# Pandas(index=267, months_left=18)
# Pandas(index=268, months_left=26)
# Pandas(index=269, months_left=33)
# Pandas(index=270, months_left=14)
# Pandas(index=271, months_left=31)
# Pandas(index=272, months_left=22)
# Pandas(index=273, months_left=31)
# Pandas(index=274, months_left=35)
# Pandas(index=275, months_left=24)
# Pandas(index=276, months_left=28)
# Pandas(index=277, months_left=19)
# Pandas(index=278, months_left=2)
# Pandas(index=279, months_left=3)
# Pandas(index=280, months_left=6)
# Pandas(index=281, months_left=35)
# Pandas(index=282, months_left=19)
# Pandas(index=283, months_left=2)
# Pandas(index=284, months_left=12)
# Pandas(index=285, months_left=3)
# Pandas(index=286, months_left=2)
# Pandas(index=287, months_left=7)
# Pandas(index=288, months_left=13)
# Pandas(index=289, months_left=4)
# Pandas(index=290, months_left=6)
# Pandas(index=291, months_left=17)
# Pandas(index=292, months_left=15)
# Pandas(index=293, months_left=16)
# Pandas(index=294, months_left=18)
# Pandas(index=295, months_left=25)
# Pandas(index=296, months_left=5)
# Pandas(index=297, months_left=7)
# Pandas(index=298, months_left=5)
# Pandas(index=299, months_left=24)
# Pandas(index=300, months_left=4)
# Pandas(index=301, months_left=31)
# Pandas(index=302, months_left=35)
# Pandas(index=303, months_left=5)
# Pandas(index=304, months_left=34)
# Pandas(index=305, months_left=25)
# Pandas(index=306, months_left=34)
# Pandas(index=307, months_left=11)
# Pandas(index=308, months_left=15)
# Pandas(index=309, months_left=30)
# Pandas(index=310, months_left=33)
# Pandas(index=311, months_left=1)
# Pandas(index=312, months_left=33)
# Pandas(index=313, months_left=28)
# Pandas(index=314, months_left=17)
# Pandas(index=315, months_left=12)
# Pandas(index=316, months_left=31)
# Pandas(index=317, months_left=22)
# Pandas(index=318, months_left=27)
# Pandas(index=319, months_left=20)
# Pandas(index=320, months_left=25)
# Pandas(index=321, months_left=17)
# Pandas(index=322, months_left=24)
# Pandas(index=323, months_left=19)
# Pandas(index=324, months_left=9)
# Pandas(index=325, months_left=30)
# Pandas(index=326, months_left=34)
# Pandas(index=327, months_left=20)
# Pandas(index=328, months_left=33)
# Pandas(index=329, months_left=24)
# Pandas(index=330, months_left=18)
# Pandas(index=331, months_left=5)
# Pandas(index=332, months_left=1)
# Pandas(index=333, months_left=30)
# Pandas(index=334, months_left=19)
# Pandas(index=335, months_left=21)
# Pandas(index=336, months_left=27)
# Pandas(index=337, months_left=1)
# Pandas(index=338, months_left=6)
# Pandas(index=339, months_left=30)
# Pandas(index=340, months_left=13)
# Pandas(index=341, months_left=23)
# Pandas(index=342, months_left=20)
# Pandas(index=343, months_left=33)
# Pandas(index=344, months_left=35)
# Pandas(index=345, months_left=15)
# Pandas(index=346, months_left=3)
# Pandas(index=347, months_left=15)
# Pandas(index=348, months_left=25)
# Pandas(index=349, months_left=3)
# Pandas(index=350, months_left=27)
# Pandas(index=351, months_left=23)
# Pandas(index=352, months_left=10)
# Pandas(index=353, months_left=31)
# Pandas(index=354, months_left=7)
# Pandas(index=355, months_left=20)
# Pandas(index=356, months_left=1)
# Pandas(index=357, months_left=35)
# Pandas(index=358, months_left=19)
# Pandas(index=359, months_left=4)
# Pandas(index=360, months_left=12)
# Pandas(index=361, months_left=23)
# Pandas(index=362, months_left=25)
# Pandas(index=363, months_left=14)
# Pandas(index=364, months_left=5)
# Pandas(index=365, months_left=9)
# Pandas(index=366, months_left=28)
# Pandas(index=367, months_left=17)
# Pandas(index=368, months_left=16)
# Pandas(index=369, months_left=28)
# Pandas(index=370, months_left=20)
# Pandas(index=371, months_left=35)
# Pandas(index=372, months_left=6)
# Pandas(index=373, months_left=23)
# Pandas(index=374, months_left=31)
# Pandas(index=375, months_left=1)
# Pandas(index=376, months_left=9)
# Pandas(index=377, months_left=28)
# Pandas(index=378, months_left=2)
# Pandas(index=379, months_left=10)
# Pandas(index=380, months_left=6)
# Pandas(index=381, months_left=11)
# Pandas(index=382, months_left=9)
# Pandas(index=383, months_left=14)
# Pandas(index=384, months_left=16)
# Pandas(index=385, months_left=35)
# Pandas(index=386, months_left=32)
# Pandas(index=387, months_left=4)
# Pandas(index=388, months_left=14)
# Pandas(index=389, months_left=5)
# Pandas(index=390, months_left=31)
# Pandas(index=391, months_left=23)
# Pandas(index=392, months_left=5)
# Pandas(index=393, months_left=9)
# Pandas(index=394, months_left=33)
# Pandas(index=395, months_left=26)
# Pandas(index=396, months_left=12)
# Pandas(index=397, months_left=24)
# Pandas(index=398, months_left=23)
# Pandas(index=399, months_left=28)
# Pandas(index=400, months_left=12)
# Pandas(index=401, months_left=24)
# Pandas(index=402, months_left=35)
# Pandas(index=403, months_left=25)
# Pandas(index=404, months_left=31)
# Pandas(index=405, months_left=32)
# Pandas(index=406, months_left=5)
# Pandas(index=407, months_left=35)
# Pandas(index=408, months_left=3)
# Pandas(index=409, months_left=10)
# Pandas(index=410, months_left=35)
# Pandas(index=411, months_left=11)
# Pandas(index=412, months_left=18)
# Pandas(index=413, months_left=34)
# Pandas(index=414, months_left=26)
# Pandas(index=415, months_left=30)
# Pandas(index=416, months_left=15)
# Pandas(index=417, months_left=13)
# Pandas(index=418, months_left=32)
# Pandas(index=419, months_left=3)
# Pandas(index=420, months_left=26)
# Pandas(index=421, months_left=26)
# Pandas(index=422, months_left=33)
# Pandas(index=423, months_left=5)
# Pandas(index=424, months_left=19)
# Pandas(index=425, months_left=16)
# Pandas(index=426, months_left=8)
# Pandas(index=427, months_left=18)
# Pandas(index=428, months_left=20)
# Pandas(index=429, months_left=5)
# Pandas(index=430, months_left=27)
# Pandas(index=431, months_left=8)
# Pandas(index=432, months_left=25)
# Pandas(index=433, months_left=2)
# Pandas(index=434, months_left=14)
# Pandas(index=435, months_left=18)
# Pandas(index=436, months_left=20)
# Pandas(index=437, months_left=2)
# Pandas(index=438, months_left=6)
# Pandas(index=439, months_left=14)
# Pandas(index=440, months_left=1)
# Pandas(index=441, months_left=23)
# Pandas(index=442, months_left=13)
# Pandas(index=443, months_left=29)
# Pandas(index=444, months_left=8)
# Pandas(index=445, months_left=30)
# Pandas(index=446, months_left=14)
# Pandas(index=447, months_left=2)
# Pandas(index=448, months_left=10)
# Pandas(index=449, months_left=22)
# Pandas(index=450, months_left=31)
# Pandas(index=451, months_left=5)
# Pandas(index=452, months_left=21)
# Pandas(index=453, months_left=15)
# Pandas(index=454, months_left=27)
# Pandas(index=455, months_left=2)
# Pandas(index=456, months_left=23)
# Pandas(index=457, months_left=9)
# Pandas(index=458, months_left=23)
# Pandas(index=459, months_left=3)
# Pandas(index=460, months_left=25)
# Pandas(index=461, months_left=23)
# Pandas(index=462, months_left=14)
# Pandas(index=463, months_left=24)
# Pandas(index=464, months_left=21)
# Pandas(index=465, months_left=18)
# Pandas(index=466, months_left=15)
# Pandas(index=467, months_left=24)
# Pandas(index=468, months_left=8)
# Pandas(index=469, months_left=24)
# Pandas(index=470, months_left=27)
# Pandas(index=471, months_left=24)
# Pandas(index=472, months_left=25)
# Pandas(index=473, months_left=22)
# Pandas(index=474, months_left=7)
# Pandas(index=475, months_left=28)
# Pandas(index=476, months_left=31)
# Pandas(index=477, months_left=13)
# Pandas(index=478, months_left=9)
# Pandas(index=479, months_left=8)
# Pandas(index=480, months_left=35)
# Pandas(index=481, months_left=22)
# Pandas(index=482, months_left=3)
# Pandas(index=483, months_left=28)
# Pandas(index=484, months_left=11)
# Pandas(index=485, months_left=25)
# Pandas(index=486, months_left=23)
# Pandas(index=487, months_left=20)
# Pandas(index=488, months_left=35)
# Pandas(index=489, months_left=26)
# Pandas(index=490, months_left=18)
# Pandas(index=491, months_left=19)
# Pandas(index=492, months_left=26)
# Pandas(index=493, months_left=30)
# Pandas(index=494, months_left=27)
# Pandas(index=495, months_left=6)
# Pandas(index=496, months_left=22)
# Pandas(index=497, months_left=21)
# Pandas(index=498, months_left=7)
# Pandas(index=499, months_left=32)
# Pandas(index=500, months_left=9)
# Pandas(index=501, months_left=23)
# Pandas(index=502, months_left=27)
# Pandas(index=503, months_left=34)
# Pandas(index=504, months_left=13)
# Pandas(index=505, months_left=12)
# Pandas(index=506, months_left=3)
# Pandas(index=507, months_left=18)
# Pandas(index=508, months_left=13)
# Pandas(index=509, months_left=2)
# Pandas(index=510, months_left=28)
# Pandas(index=511, months_left=25)
# Pandas(index=512, months_left=1)
# Pandas(index=513, months_left=18)
# Pandas(index=514, months_left=29)
# Pandas(index=515, months_left=24)
# Pandas(index=516, months_left=15)
# Pandas(index=517, months_left=12)
# Pandas(index=518, months_left=29)
# Pandas(index=519, months_left=28)
# Pandas(index=520, months_left=12)
# Pandas(index=521, months_left=3)
# Pandas(index=522, months_left=20)
# Pandas(index=523, months_left=31)
# Pandas(index=524, months_left=3)
# Pandas(index=525, months_left=18)
# Pandas(index=526, months_left=12)
# Pandas(index=527, months_left=31)
# Pandas(index=528, months_left=35)
# Pandas(index=529, months_left=7)
# Pandas(index=530, months_left=27)
# Pandas(index=531, months_left=21)
# Pandas(index=532, months_left=11)
# Pandas(index=533, months_left=29)
# Pandas(index=534, months_left=30)
# Pandas(index=535, months_left=9)
# Pandas(index=536, months_left=23)
# Pandas(index=537, months_left=21)
# Pandas(index=538, months_left=31)
# Pandas(index=539, months_left=19)
# Pandas(index=540, months_left=23)
# Pandas(index=541, months_left=27)
# Pandas(index=542, months_left=20)
# Pandas(index=543, months_left=9)
# Pandas(index=544, months_left=27)
# Pandas(index=545, months_left=19)
# Pandas(index=546, months_left=18)
# Pandas(index=547, months_left=20)
# Pandas(index=548, months_left=13)
# Pandas(index=549, months_left=35)
# Pandas(index=550, months_left=26)
# Pandas(index=551, months_left=29)
# Pandas(index=552, months_left=10)
# Pandas(index=553, months_left=33)
# Pandas(index=554, months_left=33)
# Pandas(index=555, months_left=14)
# Pandas(index=556, months_left=20)
# Pandas(index=557, months_left=1)
# Pandas(index=558, months_left=29)
# Pandas(index=559, months_left=22)
# Pandas(index=560, months_left=18)
# Pandas(index=561, months_left=33)
# Pandas(index=562, months_left=31)
# Pandas(index=563, months_left=11)
# Pandas(index=564, months_left=24)
# Pandas(index=565, months_left=6)
# Pandas(index=566, months_left=8)
# Pandas(index=567, months_left=31)
# Pandas(index=568, months_left=24)
# Pandas(index=569, months_left=22)
# Pandas(index=570, months_left=31)
# Pandas(index=571, months_left=10)
# Pandas(index=572, months_left=34)
# Pandas(index=573, months_left=12)
# Pandas(index=574, months_left=27)
# Pandas(index=575, months_left=9)
# Pandas(index=576, months_left=2)
# Pandas(index=577, months_left=5)
# Pandas(index=578, months_left=33)
# Pandas(index=579, months_left=12)
# Pandas(index=580, months_left=2)
# Pandas(index=581, months_left=21)
# Pandas(index=582, months_left=34)
# Pandas(index=583, months_left=13)
# Pandas(index=584, months_left=35)
# Pandas(index=585, months_left=12)
# Pandas(index=586, months_left=3)
# Pandas(index=587, months_left=2)
# Pandas(index=588, months_left=22)
# Pandas(index=589, months_left=27)
# Pandas(index=590, months_left=19)
# Pandas(index=591, months_left=13)
# Pandas(index=592, months_left=35)
# Pandas(index=593, months_left=17)
# Pandas(index=594, months_left=17)
# Pandas(index=595, months_left=18)
# Pandas(index=596, months_left=3)
# Pandas(index=597, months_left=28)
# Pandas(index=598, months_left=34)
# Pandas(index=599, months_left=13)
# Pandas(index=600, months_left=24)
# Pandas(index=601, months_left=26)
# Pandas(index=602, months_left=33)
# Pandas(index=603, months_left=34)
# Pandas(index=604, months_left=5)
# Pandas(index=605, months_left=30)
# Pandas(index=606, months_left=7)
# Pandas(index=607, months_left=31)
# Pandas(index=608, months_left=27)
# Pandas(index=609, months_left=4)
# Pandas(index=610, months_left=34)
# Pandas(index=611, months_left=23)
# Pandas(index=612, months_left=16)
# Pandas(index=613, months_left=34)
# Pandas(index=614, months_left=12)
# Pandas(index=615, months_left=22)
# Pandas(index=616, months_left=11)
# Pandas(index=617, months_left=24)
# Pandas(index=618, months_left=25)
# Pandas(index=619, months_left=17)
# Pandas(index=620, months_left=13)
# Pandas(index=621, months_left=34)
# Pandas(index=622, months_left=14)
# Pandas(index=623, months_left=24)
# Pandas(index=624, months_left=21)
# Pandas(index=625, months_left=12)
# Pandas(index=626, months_left=24)
# Pandas(index=627, months_left=7)
# Pandas(index=628, months_left=22)
# Pandas(index=629, months_left=13)
# Pandas(index=630, months_left=2)
# Pandas(index=631, months_left=11)
# Pandas(index=632, months_left=1)
# Pandas(index=633, months_left=33)
# Pandas(index=634, months_left=15)
# Pandas(index=635, months_left=15)
# Pandas(index=636, months_left=27)
# Pandas(index=637, months_left=31)
# Pandas(index=638, months_left=27)
# Pandas(index=639, months_left=16)
# Pandas(index=640, months_left=14)
# Pandas(index=641, months_left=28)
# Pandas(index=642, months_left=4)
# Pandas(index=643, months_left=1)
# Pandas(index=644, months_left=13)
# Pandas(index=645, months_left=4)
# Pandas(index=646, months_left=35)
# Pandas(index=647, months_left=27)
# Pandas(index=648, months_left=20)
# Pandas(index=649, months_left=29)
# Pandas(index=650, months_left=12)
# Pandas(index=651, months_left=7)
# Pandas(index=652, months_left=23)
# Pandas(index=653, months_left=23)
# Pandas(index=654, months_left=4)
# Pandas(index=655, months_left=32)
# Pandas(index=656, months_left=13)
# Pandas(index=657, months_left=27)
# Pandas(index=658, months_left=25)
# Pandas(index=659, months_left=25)
# Pandas(index=660, months_left=18)
# Pandas(index=661, months_left=5)
# Pandas(index=662, months_left=5)
# Pandas(index=663, months_left=25)
# Pandas(index=664, months_left=16)
# Pandas(index=665, months_left=2)
# Pandas(index=666, months_left=27)
# Pandas(index=667, months_left=11)
# Pandas(index=668, months_left=23)
# Pandas(index=669, months_left=15)
# Pandas(index=670, months_left=20)
# Pandas(index=671, months_left=13)
# Pandas(index=672, months_left=12)
# Pandas(index=673, months_left=7)
# Pandas(index=674, months_left=20)
# Pandas(index=675, months_left=34)
# Pandas(index=676, months_left=20)
# Pandas(index=677, months_left=20)
# Pandas(index=678, months_left=1)
# Pandas(index=679, months_left=8)
# Pandas(index=680, months_left=22)
# Pandas(index=681, months_left=23)
# Pandas(index=682, months_left=4)
# Pandas(index=683, months_left=35)
# Pandas(index=684, months_left=26)
# Pandas(index=685, months_left=22)
# Pandas(index=686, months_left=6)
# Pandas(index=687, months_left=14)
# Pandas(index=688, months_left=23)
# Pandas(index=689, months_left=26)
# Pandas(index=690, months_left=13)
# Pandas(index=691, months_left=27)
# Pandas(index=692, months_left=8)
# Pandas(index=693, months_left=8)
# Pandas(index=694, months_left=3)
# Pandas(index=695, months_left=7)
# Pandas(index=696, months_left=18)
# Pandas(index=697, months_left=14)
# Pandas(index=698, months_left=6)
# Pandas(index=699, months_left=16)
# Pandas(index=700, months_left=30)
# Pandas(index=701, months_left=27)
# Pandas(index=702, months_left=5)
# Pandas(index=703, months_left=25)
# Pandas(index=704, months_left=3)
# Pandas(index=705, months_left=32)
# Pandas(index=706, months_left=18)
# Pandas(index=707, months_left=15)
# Pandas(index=708, months_left=27)
# Pandas(index=709, months_left=12)
# Pandas(index=710, months_left=15)
# Pandas(index=711, months_left=19)
# Pandas(index=712, months_left=20)
# Pandas(index=713, months_left=16)
# Pandas(index=714, months_left=25)
# Pandas(index=715, months_left=13)
# Pandas(index=716, months_left=29)
# Pandas(index=717, months_left=26)
# Pandas(index=718, months_left=7)
# Pandas(index=719, months_left=9)
# Pandas(index=720, months_left=1)
# Pandas(index=721, months_left=22)
# Pandas(index=722, months_left=32)
# Pandas(index=723, months_left=28)
# Pandas(index=724, months_left=14)
# Pandas(index=725, months_left=9)
# Pandas(index=726, months_left=34)
# Pandas(index=727, months_left=21)
# Pandas(index=728, months_left=23)
# Pandas(index=729, months_left=14)
# Pandas(index=730, months_left=32)
# Pandas(index=731, months_left=27)
# Pandas(index=732, months_left=20)
# Pandas(index=733, months_left=25)
# Pandas(index=734, months_left=2)
# Pandas(index=735, months_left=18)
# Pandas(index=736, months_left=22)
# Pandas(index=737, months_left=20)
# Pandas(index=738, months_left=19)
# Pandas(index=739, months_left=4)
# Pandas(index=740, months_left=22)
# Pandas(index=741, months_left=4)
# Pandas(index=742, months_left=3)
# Pandas(index=743, months_left=2)
# Pandas(index=744, months_left=21)
# Pandas(index=745, months_left=2)
# Pandas(index=746, months_left=15)
# Pandas(index=747, months_left=15)
# Pandas(index=748, months_left=11)
# Pandas(index=749, months_left=20)
# Pandas(index=750, months_left=23)
# Pandas(index=751, months_left=29)
# Pandas(index=752, months_left=3)
# Pandas(index=753, months_left=22)
# Pandas(index=754, months_left=15)
# Pandas(index=755, months_left=22)
# Pandas(index=756, months_left=21)
# Pandas(index=757, months_left=9)
# Pandas(index=758, months_left=35)
# Pandas(index=759, months_left=26)
# Pandas(index=760, months_left=18)
# Pandas(index=761, months_left=22)
# Pandas(index=762, months_left=33)
# Pandas(index=763, months_left=8)
# Pandas(index=764, months_left=27)
# Pandas(index=765, months_left=14)
# Pandas(index=766, months_left=19)
# Pandas(index=767, months_left=25)
# Pandas(index=768, months_left=25)
# Pandas(index=769, months_left=7)
# Pandas(index=770, months_left=32)
# Pandas(index=771, months_left=6)
# Pandas(index=772, months_left=16)
# Pandas(index=773, months_left=30)
# Pandas(index=774, months_left=10)
# Pandas(index=775, months_left=21)
# Pandas(index=776, months_left=26)
# Pandas(index=777, months_left=7)
# Pandas(index=778, months_left=10)
# Pandas(index=779, months_left=9)
# Pandas(index=780, months_left=21)
# Pandas(index=781, months_left=23)
# Pandas(index=782, months_left=10)
# Pandas(index=783, months_left=35)
# Pandas(index=784, months_left=4)
# Pandas(index=785, months_left=10)
# Pandas(index=786, months_left=7)
# Pandas(index=787, months_left=23)
# Pandas(index=788, months_left=18)
# Pandas(index=789, months_left=4)
# Pandas(index=790, months_left=35)
# Pandas(index=791, months_left=23)
# Pandas(index=792, months_left=12)
# Pandas(index=793, months_left=26)
# Pandas(index=794, months_left=27)
# Pandas(index=795, months_left=21)
# Pandas(index=796, months_left=16)
# Pandas(index=797, months_left=4)
# Pandas(index=798, months_left=35)
# Pandas(index=799, months_left=5)
# Pandas(index=800, months_left=29)
# Pandas(index=801, months_left=14)
# Pandas(index=802, months_left=11)
# Pandas(index=803, months_left=1)
# Pandas(index=804, months_left=35)
# Pandas(index=805, months_left=1)
# Pandas(index=806, months_left=14)
# Pandas(index=807, months_left=28)
# Pandas(index=808, months_left=18)
# Pandas(index=809, months_left=27)
# Pandas(index=810, months_left=25)
# Pandas(index=811, months_left=31)
# Pandas(index=812, months_left=16)
# Pandas(index=813, months_left=7)
# Pandas(index=814, months_left=23)
# Pandas(index=815, months_left=29)
# Pandas(index=816, months_left=33)
# Pandas(index=817, months_left=11)
# Pandas(index=818, months_left=31)
# Pandas(index=819, months_left=35)
# Pandas(index=820, months_left=28)
# Pandas(index=821, months_left=7)
# Pandas(index=822, months_left=26)
# Pandas(index=823, months_left=1)
# Pandas(index=824, months_left=23)
# Pandas(index=825, months_left=22)
# Pandas(index=826, months_left=29)
# Pandas(index=827, months_left=14)
# Pandas(index=828, months_left=34)
# Pandas(index=829, months_left=5)
# Pandas(index=830, months_left=12)
# Pandas(index=831, months_left=25)
# Pandas(index=832, months_left=12)
# Pandas(index=833, months_left=30)
# Pandas(index=834, months_left=31)
# Pandas(index=835, months_left=33)
# Pandas(index=836, months_left=35)
# Pandas(index=837, months_left=21)
# Pandas(index=838, months_left=8)
# Pandas(index=839, months_left=1)
# Pandas(index=840, months_left=23)
# Pandas(index=841, months_left=21)
# Pandas(index=842, months_left=23)
# Pandas(index=843, months_left=18)
# Pandas(index=844, months_left=25)
# Pandas(index=845, months_left=23)
# Pandas(index=846, months_left=15)
# Pandas(index=847, months_left=11)
# Pandas(index=848, months_left=12)
# Pandas(index=849, months_left=19)
# Pandas(index=850, months_left=2)
# Pandas(index=851, months_left=34)
# Pandas(index=852, months_left=6)
# Pandas(index=853, months_left=28)
# Pandas(index=854, months_left=35)
# Pandas(index=855, months_left=12)
# Pandas(index=856, months_left=12)
# Pandas(index=857, months_left=13)
# Pandas(index=858, months_left=11)
# Pandas(index=859, months_left=16)
# Pandas(index=860, months_left=35)
# Pandas(index=861, months_left=35)
# Pandas(index=862, months_left=19)
# Pandas(index=863, months_left=15)
# Pandas(index=864, months_left=19)
# Pandas(index=865, months_left=2)
# Pandas(index=866, months_left=6)
# Pandas(index=867, months_left=15)
# Pandas(index=868, months_left=12)
# Pandas(index=869, months_left=10)
# Pandas(index=870, months_left=12)
# Pandas(index=871, months_left=3)
# Pandas(index=872, months_left=29)
# Pandas(index=873, months_left=19)
# Pandas(index=874, months_left=10)
# Pandas(index=875, months_left=8)
# Pandas(index=876, months_left=35)
# Pandas(index=877, months_left=12)
# Pandas(index=878, months_left=17)
# Pandas(index=879, months_left=34)
# Pandas(index=880, months_left=33)
# Pandas(index=881, months_left=3)
# Pandas(index=882, months_left=4)
# Pandas(index=883, months_left=18)
# Pandas(index=884, months_left=5)
# Pandas(index=885, months_left=13)
# Pandas(index=886, months_left=2)
# Pandas(index=887, months_left=30)
# Pandas(index=888, months_left=21)
# Pandas(index=889, months_left=23)
# Pandas(index=890, months_left=13)
# Pandas(index=891, months_left=2)
# Pandas(index=892, months_left=16)
# Pandas(index=893, months_left=33)
# Pandas(index=894, months_left=33)
# Pandas(index=895, months_left=1)
# Pandas(index=896, months_left=17)
# Pandas(index=897, months_left=2)
# Pandas(index=898, months_left=30)
# Pandas(index=899, months_left=23)
# Pandas(index=900, months_left=7)
# Pandas(index=901, months_left=24)
# Pandas(index=902, months_left=18)
# Pandas(index=903, months_left=14)
# Pandas(index=904, months_left=29)
# Pandas(index=905, months_left=25)
# Pandas(index=906, months_left=5)
# Pandas(index=907, months_left=24)
# Pandas(index=908, months_left=21)
# Pandas(index=909, months_left=16)
# Pandas(index=910, months_left=2)
# Pandas(index=911, months_left=21)
# Pandas(index=912, months_left=3)
# Pandas(index=913, months_left=28)
# Pandas(index=914, months_left=18)
# Pandas(index=915, months_left=34)
# Pandas(index=916, months_left=22)
# Pandas(index=917, months_left=31)
# Pandas(index=918, months_left=11)
# Pandas(index=919, months_left=5)
# Pandas(index=920, months_left=10)
# Pandas(index=921, months_left=3)
# Pandas(index=922, months_left=34)
# Pandas(index=923, months_left=28)
# Pandas(index=924, months_left=11)
# Pandas(index=925, months_left=9)
# Pandas(index=926, months_left=6)
# Pandas(index=927, months_left=28)
# Pandas(index=928, months_left=3)
# Pandas(index=929, months_left=2)
# Pandas(index=930, months_left=29)
# Pandas(index=931, months_left=11)
# Pandas(index=932, months_left=5)
# Pandas(index=933, months_left=27)
# Pandas(index=934, months_left=23)
# Pandas(index=935, months_left=13)
# Pandas(index=936, months_left=16)
# Pandas(index=937, months_left=17)
# Pandas(index=938, months_left=26)
# Pandas(index=939, months_left=17)
# Pandas(index=940, months_left=24)
# Pandas(index=941, months_left=2)
# Pandas(index=942, months_left=30)
# Pandas(index=943, months_left=12)
# Pandas(index=944, months_left=34)
# Pandas(index=945, months_left=35)
# Pandas(index=946, months_left=8)
# Pandas(index=947, months_left=10)
# Pandas(index=948, months_left=8)
# Pandas(index=949, months_left=30)
# Pandas(index=950, months_left=1)
# Pandas(index=951, months_left=33)
# Pandas(index=952, months_left=30)
# Pandas(index=953, months_left=6)
# Pandas(index=954, months_left=18)
# Pandas(index=955, months_left=11)
# Pandas(index=956, months_left=6)
# Pandas(index=957, months_left=31)
# Pandas(index=958, months_left=4)
# Pandas(index=959, months_left=18)
# Pandas(index=960, months_left=13)
# Pandas(index=961, months_left=31)
# Pandas(index=962, months_left=12)
# Pandas(index=963, months_left=7)
# Pandas(index=964, months_left=31)
# Pandas(index=965, months_left=16)
# Pandas(index=966, months_left=14)
# Pandas(index=967, months_left=31)
# Pandas(index=968, months_left=18)
# Pandas(index=969, months_left=15)
# Pandas(index=970, months_left=28)
# Pandas(index=971, months_left=25)
# Pandas(index=972, months_left=33)
# Pandas(index=973, months_left=8)
# Pandas(index=974, months_left=15)
# Pandas(index=975, months_left=9)
# Pandas(index=976, months_left=27)
# Pandas(index=977, months_left=6)
# Pandas(index=978, months_left=16)
# Pandas(index=979, months_left=31)
# Pandas(index=980, months_left=3)
# Pandas(index=981, months_left=26)
# Pandas(index=982, months_left=7)
# Pandas(index=983, months_left=16)
# Pandas(index=984, months_left=6)
# Pandas(index=985, months_left=16)
# Pandas(index=986, months_left=31)
# Pandas(index=987, months_left=9)
# Pandas(index=988, months_left=15)
# Pandas(index=989, months_left=1)
# Pandas(index=990, months_left=24)
# Pandas(index=991, months_left=18)
# Pandas(index=992, months_left=18)
# Pandas(index=993, months_left=25)
# Pandas(index=994, months_left=19)
# Pandas(index=995, months_left=6)
# Pandas(index=996, months_left=28)
# Pandas(index=997, months_left=32)
# Pandas(index=998, months_left=15)
# Pandas(index=999, months_left=32)
# Pandas(index=1000, months_left=4)
# Pandas(index=1001, months_left=34)
# Pandas(index=1002, months_left=17)
# Pandas(index=1003, months_left=23)
# Pandas(index=1004, months_left=5)
# Pandas(index=1005, months_left=8)
# Pandas(index=1006, months_left=3)
# Pandas(index=1007, months_left=15)
# Pandas(index=1008, months_left=1)
# Pandas(index=1009, months_left=2)
# Pandas(index=1010, months_left=28)
# Pandas(index=1011, months_left=14)
# Pandas(index=1012, months_left=22)
# Pandas(index=1013, months_left=15)
# Pandas(index=1014, months_left=25)
# Pandas(index=1015, months_left=11)
# Pandas(index=1016, months_left=7)
# Pandas(index=1017, months_left=21)
# Pandas(index=1018, months_left=2)
# Pandas(index=1019, months_left=25)
# Pandas(index=1020, months_left=6)
# Pandas(index=1021, months_left=9)
# Pandas(index=1022, months_left=6)
# Pandas(index=1023, months_left=7)
# Pandas(index=1024, months_left=15)
# Pandas(index=1025, months_left=2)
# Pandas(index=1026, months_left=20)
# Pandas(index=1027, months_left=27)
# Pandas(index=1028, months_left=21)
# Pandas(index=1029, months_left=19)
# Pandas(index=1030, months_left=5)
# Pandas(index=1031, months_left=31)
# Pandas(index=1032, months_left=18)
# Pandas(index=1033, months_left=17)
# Pandas(index=1034, months_left=13)
# Pandas(index=1035, months_left=19)
# Pandas(index=1036, months_left=27)
# Pandas(index=1037, months_left=17)
# Pandas(index=1038, months_left=15)
# Pandas(index=1039, months_left=10)
# Pandas(index=1040, months_left=29)
# Pandas(index=1041, months_left=13)
# Pandas(index=1042, months_left=5)
# Pandas(index=1043, months_left=23)
# Pandas(index=1044, months_left=33)
# Pandas(index=1045, months_left=24)
# Pandas(index=1046, months_left=6)
# Pandas(index=1047, months_left=17)
# Pandas(index=1048, months_left=29)
# Pandas(index=1049, months_left=22)
# Pandas(index=1050, months_left=11)
# Pandas(index=1051, months_left=3)
# Pandas(index=1052, months_left=35)
# Pandas(index=1053, months_left=12)
# Pandas(index=1054, months_left=15)
# Pandas(index=1055, months_left=11)
# Pandas(index=1056, months_left=33)
# Pandas(index=1057, months_left=34)
# Pandas(index=1058, months_left=4)
# Pandas(index=1059, months_left=25)
# Pandas(index=1060, months_left=23)
# Pandas(index=1061, months_left=20)
# Pandas(index=1062, months_left=6)
# Pandas(index=1063, months_left=23)
# Pandas(index=1064, months_left=17)
# Pandas(index=1065, months_left=18)
# Pandas(index=1066, months_left=13)
# Pandas(index=1067, months_left=6)
# Pandas(index=1068, months_left=6)
# Pandas(index=1069, months_left=28)
# Pandas(index=1070, months_left=35)
# Pandas(index=1071, months_left=7)
# Pandas(index=1072, months_left=1)
# Pandas(index=1073, months_left=26)
# Pandas(index=1074, months_left=4)
# Pandas(index=1075, months_left=18)
# Pandas(index=1076, months_left=29)
# Pandas(index=1077, months_left=11)
# Pandas(index=1078, months_left=26)
# Pandas(index=1079, months_left=2)
# Pandas(index=1080, months_left=2)
# Pandas(index=1081, months_left=10)
# Pandas(index=1082, months_left=33)
# Pandas(index=1083, months_left=15)
# Pandas(index=1084, months_left=31)
# Pandas(index=1085, months_left=13)
# Pandas(index=1086, months_left=14)
# Pandas(index=1087, months_left=8)
# Pandas(index=1088, months_left=28)
# Pandas(index=1089, months_left=8)
# Pandas(index=1090, months_left=33)
# Pandas(index=1091, months_left=5)
# Pandas(index=1092, months_left=9)
# Pandas(index=1093, months_left=7)
# Pandas(index=1094, months_left=24)
# Pandas(index=1095, months_left=6)
# Pandas(index=1096, months_left=12)
# Pandas(index=1097, months_left=12)
# Pandas(index=1098, months_left=20)
# Pandas(index=1099, months_left=18)
# Pandas(index=1100, months_left=29)
# Pandas(index=1101, months_left=6)
# Pandas(index=1102, months_left=6)
# Pandas(index=1103, months_left=9)
# Pandas(index=1104, months_left=15)
# Pandas(index=1105, months_left=5)
# Pandas(index=1106, months_left=21)
# Pandas(index=1107, months_left=1)
# Pandas(index=1108, months_left=5)
# Pandas(index=1109, months_left=8)
# Pandas(index=1110, months_left=2)
# Pandas(index=1111, months_left=32)
# Pandas(index=1112, months_left=11)
# Pandas(index=1113, months_left=29)
# Pandas(index=1114, months_left=8)
# Pandas(index=1115, months_left=3)
# Pandas(index=1116, months_left=2)
# Pandas(index=1117, months_left=19)
# Pandas(index=1118, months_left=33)
# Pandas(index=1119, months_left=2)
# Pandas(index=1120, months_left=31)
# Pandas(index=1121, months_left=2)
# Pandas(index=1122, months_left=3)
# Pandas(index=1123, months_left=2)
# Pandas(index=1124, months_left=16)
# Pandas(index=1125, months_left=18)
# Pandas(index=1126, months_left=7)
# Pandas(index=1127, months_left=13)
# Pandas(index=1128, months_left=28)
# Pandas(index=1129, months_left=20)
# Pandas(index=1130, months_left=28)
# Pandas(index=1131, months_left=8)
# Pandas(index=1132, months_left=1)
# Pandas(index=1133, months_left=1)
# Pandas(index=1134, months_left=12)
# Pandas(index=1135, months_left=23)
# Pandas(index=1136, months_left=35)
# Pandas(index=1137, months_left=9)
# Pandas(index=1138, months_left=19)
# Pandas(index=1139, months_left=5)
# Pandas(index=1140, months_left=27)
# Pandas(index=1141, months_left=16)
# Pandas(index=1142, months_left=4)
# Pandas(index=1143, months_left=11)
# Pandas(index=1144, months_left=13)
# Pandas(index=1145, months_left=9)
# Pandas(index=1146, months_left=34)
# Pandas(index=1147, months_left=8)
# Pandas(index=1148, months_left=32)
# Pandas(index=1149, months_left=10)
# Pandas(index=1150, months_left=19)
# Pandas(index=1151, months_left=20)
# Pandas(index=1152, months_left=29)
# Pandas(index=1153, months_left=17)
# Pandas(index=1154, months_left=2)
# Pandas(index=1155, months_left=21)
# Pandas(index=1156, months_left=30)
# Pandas(index=1157, months_left=35)
# Pandas(index=1158, months_left=32)
# Pandas(index=1159, months_left=8)
# Pandas(index=1160, months_left=27)
# Pandas(index=1161, months_left=4)
# Pandas(index=1162, months_left=11)
# Pandas(index=1163, months_left=32)
# Pandas(index=1164, months_left=9)
# Pandas(index=1165, months_left=33)
# Pandas(index=1166, months_left=31)
# Pandas(index=1167, months_left=15)
# Pandas(index=1168, months_left=4)
# Pandas(index=1169, months_left=26)
# Pandas(index=1170, months_left=6)
# Pandas(index=1171, months_left=9)
# Pandas(index=1172, months_left=14)
# Pandas(index=1173, months_left=22)
# Pandas(index=1174, months_left=24)
# Pandas(index=1175, months_left=25)
# Pandas(index=1176, months_left=11)
# Pandas(index=1177, months_left=3)
# Pandas(index=1178, months_left=1)
# Pandas(index=1179, months_left=19)
# Pandas(index=1180, months_left=6)
# Pandas(index=1181, months_left=23)
# Pandas(index=1182, months_left=2)
# Pandas(index=1183, months_left=6)
# Pandas(index=1184, months_left=1)
# Pandas(index=1185, months_left=31)
# Pandas(index=1186, months_left=33)
# Pandas(index=1187, months_left=1)
# Pandas(index=1188, months_left=6)
# Pandas(index=1189, months_left=12)
# Pandas(index=1190, months_left=21)
# Pandas(index=1191, months_left=7)
# Pandas(index=1192, months_left=30)
# Pandas(index=1193, months_left=30)
# Pandas(index=1194, months_left=30)
# Pandas(index=1195, months_left=14)
# Pandas(index=1196, months_left=34)
# Pandas(index=1197, months_left=35)
# Pandas(index=1198, months_left=21)
# Pandas(index=1199, months_left=31)
# Pandas(index=1200, months_left=2)
# Pandas(index=1201, months_left=6)
# Pandas(index=1202, months_left=14)
# Pandas(index=1203, months_left=13)
# Pandas(index=1204, months_left=9)
# Pandas(index=1205, months_left=33)
# Pandas(index=1206, months_left=11)
# Pandas(index=1207, months_left=35)
# Pandas(index=1208, months_left=3)
# Pandas(index=1209, months_left=7)
# Pandas(index=1210, months_left=23)
# Pandas(index=1211, months_left=34)
# Pandas(index=1212, months_left=20)
# Pandas(index=1213, months_left=7)
# Pandas(index=1214, months_left=29)
# Pandas(index=1215, months_left=21)
# Pandas(index=1216, months_left=28)
# Pandas(index=1217, months_left=30)
# Pandas(index=1218, months_left=17)
# Pandas(index=1219, months_left=24)
# Pandas(index=1220, months_left=15)
# Pandas(index=1221, months_left=14)
# Pandas(index=1222, months_left=11)
# Pandas(index=1223, months_left=9)
# Pandas(index=1224, months_left=25)
# Pandas(index=1225, months_left=10)
# Pandas(index=1226, months_left=6)
# Pandas(index=1227, months_left=1)
# Pandas(index=1228, months_left=22)
# Pandas(index=1229, months_left=11)
# Pandas(index=1230, months_left=14)
# Pandas(index=1231, months_left=32)
# Pandas(index=1232, months_left=9)
# Pandas(index=1233, months_left=31)
# Pandas(index=1234, months_left=20)
# Pandas(index=1235, months_left=12)
# Pandas(index=1236, months_left=30)
# Pandas(index=1237, months_left=3)
# Pandas(index=1238, months_left=5)
# Pandas(index=1239, months_left=32)
# Pandas(index=1240, months_left=14)
# Pandas(index=1241, months_left=4)
# Pandas(index=1242, months_left=26)
# Pandas(index=1243, months_left=31)
# Pandas(index=1244, months_left=21)
# Pandas(index=1245, months_left=2)
# Pandas(index=1246, months_left=12)
# Pandas(index=1247, months_left=7)
# Pandas(index=1248, months_left=30)
# Pandas(index=1249, months_left=31)
# Pandas(index=1250, months_left=26)
# Pandas(index=1251, months_left=7)
# Pandas(index=1252, months_left=1)
# Pandas(index=1253, months_left=31)
# Pandas(index=1254, months_left=11)
# Pandas(index=1255, months_left=22)
# Pandas(index=1256, months_left=6)
# Pandas(index=1257, months_left=33)
# Pandas(index=1258, months_left=16)
# Pandas(index=1259, months_left=5)
# Pandas(index=1260, months_left=4)
# Pandas(index=1261, months_left=27)
# Pandas(index=1262, months_left=27)
# Pandas(index=1263, months_left=3)
# Pandas(index=1264, months_left=9)
# Pandas(index=1265, months_left=3)
# Pandas(index=1266, months_left=14)
# Pandas(index=1267, months_left=11)
# Pandas(index=1268, months_left=6)
# Pandas(index=1269, months_left=20)
# Pandas(index=1270, months_left=19)
# Pandas(index=1271, months_left=8)
# Pandas(index=1272, months_left=25)
# Pandas(index=1273, months_left=4)
# Pandas(index=1274, months_left=19)
# Pandas(index=1275, months_left=21)
# Pandas(index=1276, months_left=5)
# Pandas(index=1277, months_left=32)
# Pandas(index=1278, months_left=22)
# Pandas(index=1279, months_left=33)
# Pandas(index=1280, months_left=22)
# Pandas(index=1281, months_left=20)
# Pandas(index=1282, months_left=20)
# Pandas(index=1283, months_left=17)
# Pandas(index=1284, months_left=28)
# Pandas(index=1285, months_left=5)
# Pandas(index=1286, months_left=14)
# Pandas(index=1287, months_left=24)
# Pandas(index=1288, months_left=27)
# Pandas(index=1289, months_left=8)
# Pandas(index=1290, months_left=12)
# Pandas(index=1291, months_left=6)
# Pandas(index=1292, months_left=35)
# Pandas(index=1293, months_left=35)
# Pandas(index=1294, months_left=9)
# Pandas(index=1295, months_left=9)
# Pandas(index=1296, months_left=19)
# Pandas(index=1297, months_left=16)
# Pandas(index=1298, months_left=17)
# Pandas(index=1299, months_left=9)
# Pandas(index=1300, months_left=21)
# Pandas(index=1301, months_left=22)
# Pandas(index=1302, months_left=26)
# Pandas(index=1303, months_left=16)
# Pandas(index=1304, months_left=31)
# Pandas(index=1305, months_left=19)
# Pandas(index=1306, months_left=12)
# Pandas(index=1307, months_left=32)
# Pandas(index=1308, months_left=28)
# Pandas(index=1309, months_left=34)
# Pandas(index=1310, months_left=33)
# Pandas(index=1311, months_left=29)
# Pandas(index=1312, months_left=13)
# Pandas(index=1313, months_left=35)
# Pandas(index=1314, months_left=23)
# Pandas(index=1315, months_left=9)
# Pandas(index=1316, months_left=24)
# Pandas(index=1317, months_left=28)
# Pandas(index=1318, months_left=13)
# Pandas(index=1319, months_left=31)
# Pandas(index=1320, months_left=17)
# Pandas(index=1321, months_left=22)
# Pandas(index=1322, months_left=32)
# Pandas(index=1323, months_left=23)
# Pandas(index=1324, months_left=10)
# Pandas(index=1325, months_left=9)
# Pandas(index=1326, months_left=20)
# Pandas(index=1327, months_left=5)
# Pandas(index=1328, months_left=5)
# Pandas(index=1329, months_left=19)
# Pandas(index=1330, months_left=14)
# Pandas(index=1331, months_left=5)
# Pandas(index=1332, months_left=27)
# Pandas(index=1333, months_left=34)
# Pandas(index=1334, months_left=22)
# Pandas(index=1335, months_left=22)
# Pandas(index=1336, months_left=11)
# Pandas(index=1337, months_left=5)
# Pandas(index=1338, months_left=1)
# Pandas(index=1339, months_left=9)
# Pandas(index=1340, months_left=21)
# Pandas(index=1341, months_left=16)
# Pandas(index=1342, months_left=35)
# Pandas(index=1343, months_left=29)
# Pandas(index=1344, months_left=2)
# Pandas(index=1345, months_left=20)
# Pandas(index=1346, months_left=12)
# Pandas(index=1347, months_left=29)
# Pandas(index=1348, months_left=10)
# Pandas(index=1349, months_left=33)
# Pandas(index=1350, months_left=4)
# Pandas(index=1351, months_left=18)
# Pandas(index=1352, months_left=22)
# Pandas(index=1353, months_left=29)
# Pandas(index=1354, months_left=19)
# Pandas(index=1355, months_left=33)
# Pandas(index=1356, months_left=3)
# Pandas(index=1357, months_left=6)
# Pandas(index=1358, months_left=31)
# Pandas(index=1359, months_left=17)
# Pandas(index=1360, months_left=33)
# Pandas(index=1361, months_left=32)
# Pandas(index=1362, months_left=15)
# Pandas(index=1363, months_left=11)
# Pandas(index=1364, months_left=20)
# Pandas(index=1365, months_left=18)
# Pandas(index=1366, months_left=25)
# Pandas(index=1367, months_left=20)
# Pandas(index=1368, months_left=12)
# Pandas(index=1369, months_left=2)
# Pandas(index=1370, months_left=29)
# Pandas(index=1371, months_left=17)
# Pandas(index=1372, months_left=32)
# Pandas(index=1373, months_left=32)
# Pandas(index=1374, months_left=25)
# Pandas(index=1375, months_left=31)
# Pandas(index=1376, months_left=29)
# Pandas(index=1377, months_left=12)
# Pandas(index=1378, months_left=6)
# Pandas(index=1379, months_left=17)
# Pandas(index=1380, months_left=27)
# Pandas(index=1381, months_left=27)
# Pandas(index=1382, months_left=2)
# Pandas(index=1383, months_left=33)
# Pandas(index=1384, months_left=13)
# Pandas(index=1385, months_left=2)
# Pandas(index=1386, months_left=7)
# Pandas(index=1387, months_left=5)
# Pandas(index=1388, months_left=11)
# Pandas(index=1389, months_left=29)
# Pandas(index=1390, months_left=33)
# Pandas(index=1391, months_left=32)
# Pandas(index=1392, months_left=9)
# Pandas(index=1393, months_left=11)
# Pandas(index=1394, months_left=22)
# Pandas(index=1395, months_left=28)
# Pandas(index=1396, months_left=9)
# Pandas(index=1397, months_left=34)
# Pandas(index=1398, months_left=9)
# Pandas(index=1399, months_left=4)
# Pandas(index=1400, months_left=1)
# Pandas(index=1401, months_left=20)
# Pandas(index=1402, months_left=34)
# Pandas(index=1403, months_left=34)
# Pandas(index=1404, months_left=17)
# Pandas(index=1405, months_left=18)
# Pandas(index=1406, months_left=5)
# Pandas(index=1407, months_left=34)
# Pandas(index=1408, months_left=14)
# Pandas(index=1409, months_left=29)
# Pandas(index=1410, months_left=22)
# Pandas(index=1411, months_left=9)
# Pandas(index=1412, months_left=27)
# ...
# Pandas(index=3238, months_left=4)
# Pandas(index=3239, months_left=8)
# Pandas(index=3240, months_left=2)
# Pandas(index=3241, months_left=22)
# Pandas(index=3242, months_left=11)
# Pandas(index=3243, months_left=25)
# Pandas(index=3244, months_left=24)
# Pandas(index=3245, months_left=28)
# Pandas(index=3246, months_left=24)
# Pandas(index=3247, months_left=11)
# Pandas(index=3248, months_left=21)
# Pandas(index=3249, months_left=35)
# Pandas(index=3250, months_left=13)
# Pandas(index=3251, months_left=23)
# Pandas(index=3252, months_left=16)
# Pandas(index=3253, months_left=28)
# Pandas(index=3254, months_left=18)
# Pandas(index=3255, months_left=19)
# Pandas(index=3256, months_left=15)
# Pandas(index=3257, months_left=8)
# Pandas(index=3258, months_left=5)
# Pandas(index=3259, months_left=21)
# Pandas(index=3260, months_left=27)
# Pandas(index=3261, months_left=17)
# Pandas(index=3262, months_left=29)
# Pandas(index=3263, months_left=31)
# Pandas(index=3264, months_left=32)
# Pandas(index=3265, months_left=8)
# Pandas(index=3266, months_left=14)
# Pandas(index=3267, months_left=15)
# Pandas(index=3268, months_left=32)
# Pandas(index=3269, months_left=21)
# Pandas(index=3270, months_left=12)
# Pandas(index=3271, months_left=15)
# Pandas(index=3272, months_left=5)
# Pandas(index=3273, months_left=32)
# Pandas(index=3274, months_left=24)
# Pandas(index=3275, months_left=19)
# Pandas(index=3276, months_left=18)
# Pandas(index=3277, months_left=2)
# Pandas(index=3278, months_left=24)
# Pandas(index=3279, months_left=35)
# Pandas(index=3280, months_left=19)
# Pandas(index=3281, months_left=4)
# Pandas(index=3282, months_left=18)
# Pandas(index=3283, months_left=33)
# Pandas(index=3284, months_left=31)
# Pandas(index=3285, months_left=11)
# Pandas(index=3286, months_left=30)
# Pandas(index=3287, months_left=33)
# Pandas(index=3288, months_left=6)
# Pandas(index=3289, months_left=8)
# Pandas(index=3290, months_left=21)
# Pandas(index=3291, months_left=15)
# Pandas(index=3292, months_left=29)
# Pandas(index=3293, months_left=6)
# Pandas(index=3294, months_left=19)
# Pandas(index=3295, months_left=19)
# Pandas(index=3296, months_left=15)
# Pandas(index=3297, months_left=8)
# Pandas(index=3298, months_left=11)
# Pandas(index=3299, months_left=6)
# Pandas(index=3300, months_left=21)
# Pandas(index=3301, months_left=31)
# Pandas(index=3302, months_left=23)
# Pandas(index=3303, months_left=11)
# Pandas(index=3304, months_left=34)
# Pandas(index=3305, months_left=14)
# Pandas(index=3306, months_left=6)
# Pandas(index=3307, months_left=26)
# Pandas(index=3308, months_left=8)
# Pandas(index=3309, months_left=32)
# Pandas(index=3310, months_left=18)
# Pandas(index=3311, months_left=1)
# Pandas(index=3312, months_left=27)
# Pandas(index=3313, months_left=23)
# Pandas(index=3314, months_left=16)
# Pandas(index=3315, months_left=20)
# Pandas(index=3316, months_left=33)
# Pandas(index=3317, months_left=29)
# Pandas(index=3318, months_left=5)
# Pandas(index=3319, months_left=19)
# Pandas(index=3320, months_left=17)
# Pandas(index=3321, months_left=25)
# Pandas(index=3322, months_left=4)
# Pandas(index=3323, months_left=23)
# Pandas(index=3324, months_left=12)
# Pandas(index=3325, months_left=34)
# Pandas(index=3326, months_left=32)
# Pandas(index=3327, months_left=26)
# Pandas(index=3328, months_left=32)
# Pandas(index=3329, months_left=5)
# Pandas(index=3330, months_left=19)
# Pandas(index=3331, months_left=19)
# Pandas(index=3332, months_left=19)
# Pandas(index=3333, months_left=32)
# Pandas(index=3334, months_left=10)
# Pandas(index=3335, months_left=9)
# Pandas(index=3336, months_left=5)
# Pandas(index=3337, months_left=27)
# Pandas(index=3338, months_left=6)
# Pandas(index=3339, months_left=4)
# Pandas(index=3340, months_left=15)
# Pandas(index=3341, months_left=33)
# Pandas(index=3342, months_left=14)
# Pandas(index=3343, months_left=28)
# Pandas(index=3344, months_left=24)
# Pandas(index=3345, months_left=28)
# Pandas(index=3346, months_left=26)
# Pandas(index=3347, months_left=17)
# Pandas(index=3348, months_left=32)
# Pandas(index=3349, months_left=27)
# Pandas(index=3350, months_left=2)
# Pandas(index=3351, months_left=30)
# Pandas(index=3352, months_left=13)
# Pandas(index=3353, months_left=18)
# Pandas(index=3354, months_left=35)
# Pandas(index=3355, months_left=13)
# Pandas(index=3356, months_left=12)
# Pandas(index=3357, months_left=26)
# Pandas(index=3358, months_left=9)
# Pandas(index=3359, months_left=28)
# Pandas(index=3360, months_left=14)
# Pandas(index=3361, months_left=28)
# Pandas(index=3362, months_left=11)
# Pandas(index=3363, months_left=5)
# Pandas(index=3364, months_left=22)
# Pandas(index=3365, months_left=17)
# Pandas(index=3366, months_left=28)
# Pandas(index=3367, months_left=25)
# Pandas(index=3368, months_left=29)
# Pandas(index=3369, months_left=31)
# Pandas(index=3370, months_left=2)
# Pandas(index=3371, months_left=18)
# Pandas(index=3372, months_left=18)
# Pandas(index=3373, months_left=35)
# Pandas(index=3374, months_left=14)
# Pandas(index=3375, months_left=7)
# Pandas(index=3376, months_left=30)
# Pandas(index=3377, months_left=8)
# Pandas(index=3378, months_left=23)
# Pandas(index=3379, months_left=3)
# Pandas(index=3380, months_left=5)
# Pandas(index=3381, months_left=27)
# Pandas(index=3382, months_left=13)
# Pandas(index=3383, months_left=5)
# Pandas(index=3384, months_left=30)
# Pandas(index=3385, months_left=5)
# Pandas(index=3386, months_left=33)
# Pandas(index=3387, months_left=1)
# Pandas(index=3388, months_left=35)
# Pandas(index=3389, months_left=17)
# Pandas(index=3390, months_left=14)
# Pandas(index=3391, months_left=3)
# Pandas(index=3392, months_left=25)
# Pandas(index=3393, months_left=35)
# Pandas(index=3394, months_left=24)
# Pandas(index=3395, months_left=3)
# Pandas(index=3396, months_left=24)
# Pandas(index=3397, months_left=33)
# Pandas(index=3398, months_left=6)
# Pandas(index=3399, months_left=15)
# Pandas(index=3400, months_left=26)
# Pandas(index=3401, months_left=24)
# Pandas(index=3402, months_left=12)
# Pandas(index=3403, months_left=17)
# Pandas(index=3404, months_left=5)
# Pandas(index=3405, months_left=31)
# Pandas(index=3406, months_left=6)
# Pandas(index=3407, months_left=7)
# Pandas(index=3408, months_left=21)
# Pandas(index=3409, months_left=11)
# Pandas(index=3410, months_left=13)
# Pandas(index=3411, months_left=13)
# Pandas(index=3412, months_left=35)
# Pandas(index=3413, months_left=4)
# Pandas(index=3414, months_left=21)
# Pandas(index=3415, months_left=18)
# Pandas(index=3416, months_left=3)
# Pandas(index=3417, months_left=18)
# Pandas(index=3418, months_left=26)
# Pandas(index=3419, months_left=8)
# Pandas(index=3420, months_left=15)
# Pandas(index=3421, months_left=22)
# Pandas(index=3422, months_left=28)
# Pandas(index=3423, months_left=17)
# Pandas(index=3424, months_left=12)
# Pandas(index=3425, months_left=34)
# Pandas(index=3426, months_left=20)
# Pandas(index=3427, months_left=15)
# Pandas(index=3428, months_left=23)
# Pandas(index=3429, months_left=1)
# Pandas(index=3430, months_left=2)
# Pandas(index=3431, months_left=12)
# Pandas(index=3432, months_left=7)
# Pandas(index=3433, months_left=32)
# Pandas(index=3434, months_left=12)
# Pandas(index=3435, months_left=11)
# Pandas(index=3436, months_left=31)
# Pandas(index=3437, months_left=16)
# Pandas(index=3438, months_left=5)
# Pandas(index=3439, months_left=31)
# Pandas(index=3440, months_left=32)
# Pandas(index=3441, months_left=26)
# Pandas(index=3442, months_left=35)
# Pandas(index=3443, months_left=14)
# Pandas(index=3444, months_left=27)
# Pandas(index=3445, months_left=24)
# Pandas(index=3446, months_left=28)
# Pandas(index=3447, months_left=2)
# Pandas(index=3448, months_left=26)
# Pandas(index=3449, months_left=29)
# Pandas(index=3450, months_left=23)
# Pandas(index=3451, months_left=35)
# Pandas(index=3452, months_left=23)
# Pandas(index=3453, months_left=9)
# Pandas(index=3454, months_left=28)
# Pandas(index=3455, months_left=18)
# Pandas(index=3456, months_left=27)
# Pandas(index=3457, months_left=26)
# Pandas(index=3458, months_left=13)
# Pandas(index=3459, months_left=19)
# Pandas(index=3460, months_left=9)
# Pandas(index=3461, months_left=35)
# Pandas(index=3462, months_left=4)
# Pandas(index=3463, months_left=2)
# Pandas(index=3464, months_left=35)
# Pandas(index=3465, months_left=21)
# Pandas(index=3466, months_left=35)
# Pandas(index=3467, months_left=34)
# Pandas(index=3468, months_left=10)
# Pandas(index=3469, months_left=3)
# Pandas(index=3470, months_left=9)
# Pandas(index=3471, months_left=31)
# Pandas(index=3472, months_left=25)
# Pandas(index=3473, months_left=3)
# Pandas(index=3474, months_left=26)
# Pandas(index=3475, months_left=10)
# Pandas(index=3476, months_left=10)
# Pandas(index=3477, months_left=7)
# Pandas(index=3478, months_left=19)
# Pandas(index=3479, months_left=32)
# Pandas(index=3480, months_left=16)
# Pandas(index=3481, months_left=24)
# Pandas(index=3482, months_left=34)
# Pandas(index=3483, months_left=10)
# Pandas(index=3484, months_left=30)
# Pandas(index=3485, months_left=27)
# Pandas(index=3486, months_left=4)
# Pandas(index=3487, months_left=31)
# Pandas(index=3488, months_left=10)
# Pandas(index=3489, months_left=26)
# Pandas(index=3490, months_left=34)
# Pandas(index=3491, months_left=28)
# Pandas(index=3492, months_left=8)
# Pandas(index=3493, months_left=32)
# Pandas(index=3494, months_left=5)
# Pandas(index=3495, months_left=4)
# Pandas(index=3496, months_left=31)
# Pandas(index=3497, months_left=30)
# Pandas(index=3498, months_left=22)
# Pandas(index=3499, months_left=30)
# Pandas(index=3500, months_left=27)
# Pandas(index=3501, months_left=2)
# Pandas(index=3502, months_left=19)
# Pandas(index=3503, months_left=30)
# Pandas(index=3504, months_left=3)
# Pandas(index=3505, months_left=30)
# Pandas(index=3506, months_left=1)
# Pandas(index=3507, months_left=7)
# Pandas(index=3508, months_left=16)
# Pandas(index=3509, months_left=28)
# Pandas(index=3510, months_left=6)
# Pandas(index=3511, months_left=35)
# Pandas(index=3512, months_left=12)
# Pandas(index=3513, months_left=27)
# Pandas(index=3514, months_left=18)
# Pandas(index=3515, months_left=32)
# Pandas(index=3516, months_left=17)
# Pandas(index=3517, months_left=2)
# Pandas(index=3518, months_left=35)
# Pandas(index=3519, months_left=17)
# Pandas(index=3520, months_left=27)
# Pandas(index=3521, months_left=24)
# Pandas(index=3522, months_left=33)
# Pandas(index=3523, months_left=17)
# Pandas(index=3524, months_left=11)
# Pandas(index=3525, months_left=35)
# Pandas(index=3526, months_left=31)
# Pandas(index=3527, months_left=8)
# Pandas(index=3528, months_left=2)
# Pandas(index=3529, months_left=24)
# Pandas(index=3530, months_left=15)
# Pandas(index=3531, months_left=18)
# Pandas(index=3532, months_left=5)
# Pandas(index=3533, months_left=18)
# Pandas(index=3534, months_left=4)
# Pandas(index=3535, months_left=27)
# Pandas(index=3536, months_left=24)
# Pandas(index=3537, months_left=9)
# Pandas(index=3538, months_left=32)
# Pandas(index=3539, months_left=13)
# Pandas(index=3540, months_left=15)
# Pandas(index=3541, months_left=10)
# Pandas(index=3542, months_left=22)
# Pandas(index=3543, months_left=34)
# Pandas(index=3544, months_left=12)
# Pandas(index=3545, months_left=1)
# Pandas(index=3546, months_left=13)
# Pandas(index=3547, months_left=19)
# Pandas(index=3548, months_left=6)
# Pandas(index=3549, months_left=13)
# Pandas(index=3550, months_left=8)
# Pandas(index=3551, months_left=21)
# Pandas(index=3552, months_left=35)
# Pandas(index=3553, months_left=7)
# Pandas(index=3554, months_left=17)
# Pandas(index=3555, months_left=10)
# Pandas(index=3556, months_left=1)
# Pandas(index=3557, months_left=15)
# Pandas(index=3558, months_left=30)
# Pandas(index=3559, months_left=3)
# Pandas(index=3560, months_left=14)
# Pandas(index=3561, months_left=16)
# Pandas(index=3562, months_left=1)
# Pandas(index=3563, months_left=32)
# Pandas(index=3564, months_left=4)
# Pandas(index=3565, months_left=10)
# Pandas(index=3566, months_left=18)
# Pandas(index=3567, months_left=26)
# Pandas(index=3568, months_left=30)
# Pandas(index=3569, months_left=23)
# Pandas(index=3570, months_left=3)
# Pandas(index=3571, months_left=30)
# Pandas(index=3572, months_left=7)
# Pandas(index=3573, months_left=3)
# Pandas(index=3574, months_left=13)
# Pandas(index=3575, months_left=12)
# Pandas(index=3576, months_left=2)
# Pandas(index=3577, months_left=5)
# Pandas(index=3578, months_left=22)
# Pandas(index=3579, months_left=28)
# Pandas(index=3580, months_left=26)
# Pandas(index=3581, months_left=5)
# Pandas(index=3582, months_left=21)
# Pandas(index=3583, months_left=35)
# Pandas(index=3584, months_left=3)
# Pandas(index=3585, months_left=25)
# Pandas(index=3586, months_left=21)
# Pandas(index=3587, months_left=31)
# Pandas(index=3588, months_left=13)
# Pandas(index=3589, months_left=33)
# Pandas(index=3590, months_left=20)
# Pandas(index=3591, months_left=25)
# Pandas(index=3592, months_left=33)
# Pandas(index=3593, months_left=21)
# Pandas(index=3594, months_left=7)
# Pandas(index=3595, months_left=30)
# Pandas(index=3596, months_left=31)
# Pandas(index=3597, months_left=11)
# Pandas(index=3598, months_left=19)
# Pandas(index=3599, months_left=25)
# Pandas(index=3600, months_left=19)
# Pandas(index=3601, months_left=15)
# Pandas(index=3602, months_left=4)
# Pandas(index=3603, months_left=17)
# Pandas(index=3604, months_left=33)
# Pandas(index=3605, months_left=31)
# Pandas(index=3606, months_left=14)
# Pandas(index=3607, months_left=3)
# Pandas(index=3608, months_left=28)
# Pandas(index=3609, months_left=8)
# Pandas(index=3610, months_left=11)
# Pandas(index=3611, months_left=2)
# Pandas(index=3612, months_left=8)
# Pandas(index=3613, months_left=20)
# Pandas(index=3614, months_left=3)
# Pandas(index=3615, months_left=16)
# Pandas(index=3616, months_left=29)
# Pandas(index=3617, months_left=2)
# Pandas(index=3618, months_left=18)
# Pandas(index=3619, months_left=7)
# Pandas(index=3620, months_left=22)
# Pandas(index=3621, months_left=12)
# Pandas(index=3622, months_left=14)
# Pandas(index=3623, months_left=32)
# Pandas(index=3624, months_left=34)
# Pandas(index=3625, months_left=15)
# Pandas(index=3626, months_left=6)
# Pandas(index=3627, months_left=32)
# Pandas(index=3628, months_left=6)
# Pandas(index=3629, months_left=31)
# Pandas(index=3630, months_left=29)
# Pandas(index=3631, months_left=18)
# Pandas(index=3632, months_left=14)
# Pandas(index=3633, months_left=9)
# Pandas(index=3634, months_left=32)
# Pandas(index=3635, months_left=22)
# Pandas(index=3636, months_left=34)
# Pandas(index=3637, months_left=22)
# Pandas(index=3638, months_left=5)
# Pandas(index=3639, months_left=32)
# Pandas(index=3640, months_left=8)
# Pandas(index=3641, months_left=20)
# Pandas(index=3642, months_left=20)
# Pandas(index=3643, months_left=13)
# Pandas(index=3644, months_left=31)
# Pandas(index=3645, months_left=8)
# Pandas(index=3646, months_left=29)
# Pandas(index=3647, months_left=22)
# Pandas(index=3648, months_left=6)
# Pandas(index=3649, months_left=8)
# Pandas(index=3650, months_left=20)
# Pandas(index=3651, months_left=3)
# Pandas(index=3652, months_left=14)
# Pandas(index=3653, months_left=32)
# Pandas(index=3654, months_left=6)
# Pandas(index=3655, months_left=27)
# Pandas(index=3656, months_left=18)
# Pandas(index=3657, months_left=11)
# Pandas(index=3658, months_left=6)
# Pandas(index=3659, months_left=13)
# Pandas(index=3660, months_left=20)
# Pandas(index=3661, months_left=20)
# Pandas(index=3662, months_left=25)
# Pandas(index=3663, months_left=19)
# Pandas(index=3664, months_left=14)
# Pandas(index=3665, months_left=30)
# Pandas(index=3666, months_left=12)
# Pandas(index=3667, months_left=32)
# Pandas(index=3668, months_left=4)
# Pandas(index=3669, months_left=31)
# Pandas(index=3670, months_left=16)
# Pandas(index=3671, months_left=10)
# Pandas(index=3672, months_left=23)
# Pandas(index=3673, months_left=10)
# Pandas(index=3674, months_left=31)
# Pandas(index=3675, months_left=21)
# Pandas(index=3676, months_left=5)
# Pandas(index=3677, months_left=3)
# Pandas(index=3678, months_left=1)
# Pandas(index=3679, months_left=16)
# Pandas(index=3680, months_left=7)
# Pandas(index=3681, months_left=18)
# Pandas(index=3682, months_left=9)
# Pandas(index=3683, months_left=10)
# Pandas(index=3684, months_left=17)
# Pandas(index=3685, months_left=12)
# Pandas(index=3686, months_left=15)
# Pandas(index=3687, months_left=31)
# Pandas(index=3688, months_left=31)
# Pandas(index=3689, months_left=2)
# Pandas(index=3690, months_left=10)
# Pandas(index=3691, months_left=13)
# Pandas(index=3692, months_left=15)
# Pandas(index=3693, months_left=24)
# Pandas(index=3694, months_left=23)
# Pandas(index=3695, months_left=6)
# Pandas(index=3696, months_left=9)
# Pandas(index=3697, months_left=5)
